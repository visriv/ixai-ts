# %%
 # Short aliases for readability
KEY_ALIASES = {
        # dataset
        "dataset.num_samples": "n",
        "dataset.num_series": "d",
        "dataset.num_features": "d",
        "dataset.seq_len": "L",
        "dataset.window_size": "w",
        "dataset.num_interactions": "m",
        "dataset.autocorr_coeff": "gamma",
        
        "dataset.cross_coef": "alpha",
        "dataset.trend_window_size": "tws",
        "dataset.label_mode": "lbl",
        # model
        "model.name": "m",
        "model.d_model": "dm",
        "model.hidden": "h",
        "model.layers": "ly",
        "model.n_heads": "H",

        # training
        "training.epochs": "ep",
        "training.batch_size": "bs",
        "training.lr": "lr",
        "training.weight_decay": "wd",


        # pointwise

        "pointwise.explainer.name": "xai",
        "pointwise.explainer.params.steps": "steps",

        # pairwise
        "pairwise.interaction_method.name": "im",
        "pairwise.tau_max": "taumax",
        "pairwise.K": "K",
        "pairwise.batch_size": "bsval",
        "pairwise.params.num_permutations": "nperm"
    }

import json

def load_pointwise_metrics(run_dir):
    """
    Load pointwise metrics if present.
    Returns flat dict with prefixed keys.
    """
    out = {}

    std_path = run_dir / "pointwise_metrics.json"
    hug_path = run_dir / "pointwise_metrics_hugues.json"

    if std_path.exists():
        with open(std_path) as f:
            d = json.load(f)
        for k, v in d.items():
            out[f"pointwise.{k}"] = v

    if hug_path.exists():
        with open(hug_path) as f:
            d = json.load(f)
        for k, v in d.items():
            out[f"pointwise.hug_{k}"] = v

    return out

# %%
import os
import re
import json
from pathlib import Path
from collections import defaultdict
import pandas as pd
import numpy as np

RUNS_ROOT = Path("../runs_new")

DATASETS_OF_INTEREST = {"var_local", "var_nonlocal"}  # you said focus first two

# ----------------------------
# Helpers: safe IO
# ----------------------------
def safe_read_json(p: Path):
    try:
        with open(p, "r") as f:
            return json.load(f)
    except Exception:
        return None

def safe_glob_one(d: Path, pattern: str):
    xs = list(d.glob(pattern))
    return xs[0] if xs else None

# ----------------------------
# Parsing utilities
# ----------------------------
# captures tokens like: a1_0.2, noise=0.1, d_model=64, tau_max25 (partial handled below)
KV_RE = re.compile(r"(?P<key>[A-Za-z][A-Za-z0-9]*)[=_](?P<val>[-+]?\d*\.?\d+(?:e[-+]?\d+)?)")

# captures tokens like: tau25, perm20, ep100, bs32 etc.
# PREFIXNUM_RE = re.compile(r"^(?P<key>[A-Za-z]+)(?P<val>[-+]?\d*\.?\d+(?:e[-+]?\d+)?)$")
PREFIXNUM_RE = re.compile(
    r"^(?P<key>[A-Za-z]+)(?P<val>[-+]?\d*\.?\d+(?:e[-+]?\d+)?)$"
)


def cast_num(s: str):
    # int if clean else float
    try:
        if re.fullmatch(r"[-+]?\d+", s):
            return int(s)
        return float(s)
    except Exception:
        return s

def parse_params_from_parts(parts):
    """
    Parse params from path components using:
    - key=value or key_value
    - prefix+number tokens (bs32, ep100, tau25, perm20)
    """
    params = {}
    for part in parts:
        # split further on common delimiters
        subtoks = re.split(r"[,\s]+", part)
        for tok in subtoks:
            if not tok:
                continue

            # key=val or key_val
            m = KV_RE.search(tok)
            if m:
                k = m.group("key")
                v = cast_num(m.group("val"))
                params[k] = v
                continue

            # prefix+number (e.g., bs32, ep100, tau25, perm20)
            m2 = PREFIXNUM_RE.match(tok)
            if m2:
                k = m2.group("key")
                v = cast_num(m2.group("val"))
                # only accept if key looks like known run hyperparam prefixes
                ALLOWED_PREFIX_KEYS = {
                    # dataset
                    "a", "n", "d", "L", "w", "m", "gamma", "alpha", "tws",
                    # model
                    "dm", "h", "ly", "H",
                    # training
                    "bs", "ep", "lr", "wd",
                    # xai
                    "steps",
                    # pairwise
                    "taumax", "K", "nperm",
                }

                if k in ALLOWED_PREFIX_KEYS:
                    params[k] = v

    return params

def find_dataset_in_path(parts):
    for p in parts:
        pl = p.lower()
        if pl in {"var_local", "var_nonlocal", "cltts"}:
            return pl
    return None

def find_model_in_path(parts):
    # add more model names if needed
    known = {"transformer", "lstm", "tcn"}
    for p in parts:
        pl = p.lower()
        if pl in known:
            return pl
    return None

def infer_interaction_method(run_dir: Path):
    # your pipeline: interaction_curves_{method}.pkl
    for p in run_dir.glob("interaction_curves_*.pkl"):
        name = p.stem  # interaction_curves_ih
        m = name.split("interaction_curves_")[-1]
        return m
    return None

# ----------------------------
# Identify run directories
# ----------------------------
POINTWISE_EXPLAINERS = {"ig", "deeplift", "gradshap"}


RUN_MARKERS = [
    "pairwise_faithfulness_metrics.json",
    "pointwise_metrics.json",
    "history.json",
    "metrics1.json",
]

def is_run_dir(d: Path):
    if not d.is_dir():
        return False
    for mk in RUN_MARKERS:
        if (d / mk).exists():
            return True
    # also treat presence of interaction_curves_*.pkl as run dir
    if list(d.glob("interaction_curves_*.pkl")):
        return True
    return False

def collect_run_dirs(root: Path):
    run_dirs = []
    for dirpath, dirnames, filenames in os.walk(root):
        d = Path(dirpath)
        if is_run_dir(d):
            run_dirs.append(d)
    return sorted(set(run_dirs))



# ----------------------------
# Extract a row from a run dir
# ----------------------------
def extract_run_record(run_dir: Path):
    parts = run_dir.parts

    rec = {
        "run_dir": str(run_dir),
        "dataset": find_dataset_in_path(parts),
        "model": find_model_in_path(parts),
        "interaction_method": infer_interaction_method(run_dir),
    }

    # 1) If meta.json exists, trust it most
    meta = safe_read_json(run_dir / "meta.json")
    if meta:
        # attempt common schemas
        # meta might contain nested cfg, dataset, model, etc.
        rec["meta_present"] = True

        # dataset
        if "dataset" in meta and isinstance(meta["dataset"], dict):
            rec["dataset"] = rec["dataset"] or meta["dataset"].get("name")
            # copy scalar dataset params
            for k, v in meta["dataset"].items():
                if isinstance(v, (int, float, str, bool)):
                    rec[f"dataset.{k}"] = v

        # model
        if "model" in meta and isinstance(meta["model"], dict):
            rec["model"] = rec["model"] or meta["model"].get("name")
            for k, v in meta["model"].items():
                if isinstance(v, (int, float, str, bool)):
                    rec[f"model.{k}"] = v

        # pairwise / xai params
        for topk in ["pairwise", "pointwise", "pointwise_xai"]:
            if topk in meta and isinstance(meta[topk], dict):
                for k, v in meta[topk].items():
                    if isinstance(v, (int, float, str, bool)):
                        rec[f"{topk}.{k}"] = v

    else:
        rec["meta_present"] = False

    # 2) Parse remaining params from directory tokens (works even without meta)
    parsed = parse_params_from_parts(parts)

    # Normalize a few likely keys to your naming
    key_map = {
        "taumax": "tau_max",
        "tau": "tau_max",
        "perm": "num_permutations",
        "bs": "batch_size",
        "ep": "epochs",
    }
    for k, v in parsed.items():
        nk = key_map.get(k, k)
        rec[nk] = v

    # 3) Load metrics (if exist)
    pw = safe_read_json(run_dir / "pointwise_metrics.json")
    if pw:
        for k, v in pw.items():
            if isinstance(v, (int, float, str, bool)):
                rec[f"pointwise.{k}"] = v

    pair = safe_read_json(run_dir / "pairwise_faithfulness_metrics.json")
    if pair:
        # flatten a few important ones
        gr = pair.get("graph_recovery", {})
        if "lag_sensitive" in gr:
            for k, v in gr["lag_sensitive"].items():
                if isinstance(v, (int, float)):
                    rec[f"pairwise.ls.{k}"] = float(v)
        if "lag_agnostic" in gr:
            for k, v in gr["lag_agnostic"].items():
                if isinstance(v, (int, float)):
                    rec[f"pairwise.la.{k}"] = float(v)

        ll = pair.get("lag_locality", {})
        for k, v in ll.items():
            if isinstance(v, (int, float)):
                rec[f"pairwise.lag_locality.{k}"] = float(v)

        sc = pair.get("strength_calibration", {})
        for k, v in sc.items():
            if isinstance(v, (int, float)):
                rec[f"pairwise.strength.{k}"] = float(v)

        if "threshold_delta" in gr:
            rec["pairwise.delta"] = gr["threshold_delta"]

    hist = safe_read_json(run_dir / "history.json")
    if hist and isinstance(hist, list) and len(hist) > 0:
        last = hist[-1]
        for k, v in last.items():
            if isinstance(v, (int, float)):
                rec[f"clf.{k}"] = float(v)

    # --------------------------------------------------
    # Pointwise metrics (IG / DeepLIFT / GradSHAP)
    # --------------------------------------------------
    if rec.get("pointwise.explainer.name") in POINTWISE_EXPLAINERS:
        pm = load_pointwise_metrics(run_dir)
        rec.update(pm)


    # 4) Small convenience: bring common dataset params into top-level if present
    for k in ["a1", "noise", "rho", "gamma", "window_size"]:
        if k not in rec:
            # try dataset.a1 style
            if f"dataset.{k}" in rec:
                rec[k] = rec[f"dataset.{k}"]

    return rec

def apply_key_aliases(rec, key_aliases):
    out = {}
    for k, v in rec.items():
        alias = key_aliases.get(k, k)
        out[alias] = v
    return out



# ----------------------------
# Hyperparam discovery printer
# ----------------------------
def print_discovered_hyperparams(df, keys=None):
    if keys is None:
        # smart default: show only keys that vary and are "param-like"
        candidate = []
        for c in df.columns:
            if c in {"run_dir"}:
                continue
            if any(c.endswith(suf) for suf in [".name"]) or c.startswith(("dataset.", "model.", "pairwise.", "pointwise.")) or c in {
                "dataset","model","interaction_method","a1","noise","tau_max","num_permutations","d_model","layers","hidden","batch_size","epochs"
            }:
                candidate.append(c)
        keys = candidate

    print("🔎 Discovered hyperparams in run dirs:")
    for k in sorted(set(keys)):
        if k not in df.columns:
            continue
        vals = df[k].dropna().unique()
        if len(vals) <= 1:
            continue
        # sort nicely (numbers then strings)
        try:
            vals_sorted = sorted(vals, key=lambda x: (isinstance(x, str), x))
        except Exception:
            vals_sorted = list(vals)
        print(f"  {k}: {vals_sorted}")

# %%
# ============================
# MAIN
# ============================
run_dirs = collect_run_dirs(RUNS_ROOT)
print(f"Found {len(run_dirs)} run dirs under {RUNS_ROOT}")
# Out:
# Found 272 run dirs under ../runs_new

# %%
df
# Out:
#                                                run_dir       dataset  \
# 149  ../runs_new/var_local_a10.4_n400_d3_L50_split_...     var_local
# 155  ../runs_new/var_local_a10.4_n400_d3_L50_split_...     var_local
# 170  ../runs_new/var_local_a10.8_n400_d3_L50_split_...     var_local
# 96   ../runs_new/var_local_a10.05_n400_d3_L50_split...     var_local
# 81   ../runs_new/var_local_a10.05_n400_d3_L50_split...     var_local
# 176  ../runs_new/var_local_a10.8_n400_d3_L50_split_...     var_local
# 182  ../runs_new/var_local_a10.8_n400_d3_L50_split_...     var_local
# 80   ../runs_new/var_local_a10.05_n400_d3_L50_split...     var_local
# 128  ../runs_new/var_local_a10.2_n400_d3_L50_split_...     var_local
# 161  ../runs_new/var_local_a10.4_n400_d3_L50_split_...     var_local
# 95   ../runs_new/var_local_a10.05_n400_d3_L50_split...     var_local
# 119  ../runs_new/var_local_a10.1_n400_d3_L50_split_...     var_local
# 106  ../runs_new/var_local_a10.1_n400_d3_L50_split_...     var_local
# 94   ../runs_new/var_local_a10.05_n400_d3_L50_split...     var_local
# 87   ../runs_new/var_local_a10.05_n400_d3_L50_split...     var_local
# 140  ../runs_new/var_local_a10.2_n400_d3_L50_split_...     var_local
# 88   ../runs_new/var_local_a10.05_n400_d3_L50_split...     var_local
# 134  ../runs_new/var_local_a10.2_n400_d3_L50_split_...     var_local
# 112  ../runs_new/var_local_a10.1_n400_d3_L50_split_...     var_local
# 118  ../runs_new/var_local_a10.1_n400_d3_L50_split_...     var_local
# 167  ../runs_new/var_local_a10.8_n400_d3_L50_split_...     var_local
# 168  ../runs_new/var_local_a10.8_n400_d3_L50_split_...     var_local
# 169  ../runs_new/var_local_a10.8_n400_d3_L50_split_...     var_local
# 78   ../runs_new/var_local_a10.05_n400_d3_L50_split...     var_local
# 103  ../runs_new/var_local_a10.1_n400_d3_L50_split_...     var_local
# 126  ../runs_new/var_local_a10.2_n400_d3_L50_split_...     var_local
# 127  ../runs_new/var_local_a10.2_n400_d3_L50_split_...     var_local
# 146  ../runs_new/var_local_a10.4_n400_d3_L50_split_...     var_local
# 147  ../runs_new/var_local_a10.4_n400_d3_L50_split_...     var_local
# 105  ../runs_new/var_local_a10.1_n400_d3_L50_split_...     var_local
# 104  ../runs_new/var_local_a10.1_n400_d3_L50_split_...     var_local
# 125  ../runs_new/var_local_a10.2_n400_d3_L50_split_...     var_local
# 77   ../runs_new/var_local_a10.05_n400_d3_L50_split...     var_local
# 79   ../runs_new/var_local_a10.05_n400_d3_L50_split...     var_local
# 148  ../runs_new/var_local_a10.4_n400_d3_L50_split_...     var_local
# 245  ../runs_new/var_nonlocal_a100.75_a90.7_edge10[...  var_nonlocal
# 203  ../runs_new/var_nonlocal_a100.75_a90.5_edge10[...  var_nonlocal
# 254  ../runs_new/var_nonlocal_a100.75_a90.8_edge10[...  var_nonlocal
# 224  ../runs_new/var_nonlocal_a100.75_a90.6_edge10[...  var_nonlocal
# 233  ../runs_new/var_nonlocal_a100.75_a90.7_edge10[...  var_nonlocal
# 239  ../runs_new/var_nonlocal_a100.75_a90.7_edge10[...  var_nonlocal
# 191  ../runs_new/var_nonlocal_a100.75_a90.5_edge10[...  var_nonlocal
# 197  ../runs_new/var_nonlocal_a100.75_a90.5_edge10[...  var_nonlocal
# 260  ../runs_new/var_nonlocal_a100.75_a90.8_edge10[...  var_nonlocal
# 212  ../runs_new/var_nonlocal_a100.75_a90.6_edge10[...  var_nonlocal
# 218  ../runs_new/var_nonlocal_a100.75_a90.6_edge10[...  var_nonlocal
# 266  ../runs_new/var_nonlocal_a100.75_a90.8_edge10[...  var_nonlocal
# 251  ../runs_new/var_nonlocal_a100.75_a90.8_edge10[...  var_nonlocal
# 209  ../runs_new/var_nonlocal_a100.75_a90.6_edge10[...  var_nonlocal
# 211  ../runs_new/var_nonlocal_a100.75_a90.6_edge10[...  var_nonlocal
# 210  ../runs_new/var_nonlocal_a100.75_a90.6_edge10[...  var_nonlocal
# 252  ../runs_new/var_nonlocal_a100.75_a90.8_edge10[...  var_nonlocal
# 190  ../runs_new/var_nonlocal_a100.75_a90.5_edge10[...  var_nonlocal
# 189  ../runs_new/var_nonlocal_a100.75_a90.5_edge10[...  var_nonlocal
# 188  ../runs_new/var_nonlocal_a100.75_a90.5_edge10[...  var_nonlocal
# 230  ../runs_new/var_nonlocal_a100.75_a90.7_edge10[...  var_nonlocal
# 253  ../runs_new/var_nonlocal_a100.75_a90.8_edge10[...  var_nonlocal
# 232  ../runs_new/var_nonlocal_a100.75_a90.7_edge10[...  var_nonlocal
# 231  ../runs_new/var_nonlocal_a100.75_a90.7_edge10[...  var_nonlocal
#
#            model interaction_method  meta_present  dataset.name  \
# 149  transformer               None          True     var_local
# 155  transformer               None          True     var_local
# 170  transformer               None          True     var_local
# 96   transformer               None          True     var_local
# 81   transformer               None          True     var_local
# 176  transformer               None          True     var_local
# 182  transformer               None          True     var_local
# 80   transformer               None          True     var_local
# 128  transformer               None          True     var_local
# 161  transformer               None          True     var_local
# 95   transformer               None          True     var_local
# 119  transformer               None          True     var_local
# 106  transformer               None          True     var_local
# 94   transformer               None          True     var_local
# 87   transformer               None          True     var_local
# 140  transformer               None          True     var_local
# 88   transformer               None          True     var_local
# 134  transformer               None          True     var_local
# 112  transformer               None          True     var_local
# 118  transformer               None          True     var_local
# 167         lstm               None          True     var_local
# 168         lstm               None          True     var_local
# 169         lstm               None          True     var_local
# 78          lstm               None          True     var_local
# 103         lstm               None          True     var_local
# 126         lstm               None          True     var_local
# 127         lstm               None          True     var_local
# 146         lstm               None          True     var_local
# 147         lstm               None          True     var_local
# 105         lstm               None          True     var_local
# 104         lstm               None          True     var_local
# 125         lstm               None          True     var_local
# 77          lstm               None          True     var_local
# 79          lstm               None          True     var_local
# 148         lstm               None          True     var_local
# 245  transformer               None          True  var_nonlocal
# 203  transformer               None          True  var_nonlocal
# 254  transformer               None          True  var_nonlocal
# 224  transformer               None          True  var_nonlocal
# 233  transformer               None          True  var_nonlocal
# 239  transformer               None          True  var_nonlocal
# 191  transformer               None          True  var_nonlocal
# 197  transformer               None          True  var_nonlocal
# 260  transformer               None          True  var_nonlocal
# 212  transformer               None          True  var_nonlocal
# 218  transformer               None          True  var_nonlocal
# 266  transformer               None          True  var_nonlocal
# 251         lstm               None          True  var_nonlocal
# 209         lstm               None          True  var_nonlocal
# 211         lstm               None          True  var_nonlocal
# 210         lstm               None          True  var_nonlocal
# 252         lstm               None          True  var_nonlocal
# 190         lstm               None          True  var_nonlocal
# 189         lstm               None          True  var_nonlocal
# 188         lstm               None          True  var_nonlocal
# 230         lstm               None          True  var_nonlocal
# 253         lstm               None          True  var_nonlocal
# 232         lstm               None          True  var_nonlocal
# 231         lstm               None          True  var_nonlocal
#
#     dataset.all_times      n     L   w  ...    d  dataset.a1  \
# 149             False  400.0  50.0 NaN  ...  3.0        0.40
# 155             False  400.0  50.0 NaN  ...  3.0        0.40
# 170             False  400.0  50.0 NaN  ...  3.0        0.80
# 96              False  400.0  50.0 NaN  ...  3.0        0.05
# 81              False  400.0  50.0 NaN  ...  3.0        0.05
# 176             False  400.0  50.0 NaN  ...  3.0        0.80
# 182             False  400.0  50.0 NaN  ...  3.0        0.80
# 80              False  400.0  50.0 NaN  ...  3.0        0.05
# 128             False  400.0  50.0 NaN  ...  3.0        0.20
# 161             False  400.0  50.0 NaN  ...  3.0        0.40
# 95              False  400.0  50.0 NaN  ...  3.0        0.05
# 119             False  400.0  50.0 NaN  ...  3.0        0.10
# 106             False  400.0  50.0 NaN  ...  3.0        0.10
# 94              False  400.0  50.0 NaN  ...  3.0        0.05
# 87              False  400.0  50.0 NaN  ...  3.0        0.05
# 140             False  400.0  50.0 NaN  ...  3.0        0.20
# 88              False  400.0  50.0 NaN  ...  3.0        0.05
# 134             False  400.0  50.0 NaN  ...  3.0        0.20
# 112             False  400.0  50.0 NaN  ...  3.0        0.10
# 118             False  400.0  50.0 NaN  ...  3.0        0.10
# 167             False  400.0  50.0 NaN  ...  3.0        0.80
# 168             False  400.0  50.0 NaN  ...  3.0        0.80
# 169             False  400.0  50.0 NaN  ...  3.0        0.80
# 78              False  400.0  50.0 NaN  ...  3.0        0.05
# 103             False  400.0  50.0 NaN  ...  3.0        0.10
# 126             False  400.0  50.0 NaN  ...  3.0        0.20
# 127             False  400.0  50.0 NaN  ...  3.0        0.20
# 146             False  400.0  50.0 NaN  ...  3.0        0.40
# 147             False  400.0  50.0 NaN  ...  3.0        0.40
# 105             False  400.0  50.0 NaN  ...  3.0        0.10
# 104             False  400.0  50.0 NaN  ...  3.0        0.10
# 125             False  400.0  50.0 NaN  ...  3.0        0.20
# 77              False  400.0  50.0 NaN  ...  3.0        0.05
# 79              False  400.0  50.0 NaN  ...  3.0        0.05
# 148             False  400.0  50.0 NaN  ...  3.0        0.40
# 245             False  400.0  50.0 NaN  ...  3.0         NaN
# 203             False  400.0  50.0 NaN  ...  3.0         NaN
# 254             False  400.0  50.0 NaN  ...  3.0         NaN
# 224             False  400.0  50.0 NaN  ...  3.0         NaN
# 233             False  400.0  50.0 NaN  ...  3.0         NaN
# 239             False  400.0  50.0 NaN  ...  3.0         NaN
# 191             False  400.0  50.0 NaN  ...  3.0         NaN
# 197             False  400.0  50.0 NaN  ...  3.0         NaN
# 260             False  400.0  50.0 NaN  ...  3.0         NaN
# 212             False  400.0  50.0 NaN  ...  3.0         NaN
# 218             False  400.0  50.0 NaN  ...  3.0         NaN
# 266             False  400.0  50.0 NaN  ...  3.0         NaN
# 251             False  400.0  50.0 NaN  ...  3.0         NaN
# 209             False  400.0  50.0 NaN  ...  3.0         NaN
# 211             False  400.0  50.0 NaN  ...  3.0         NaN
# 210             False  400.0  50.0 NaN  ...  3.0         NaN
# 252             False  400.0  50.0 NaN  ...  3.0         NaN
# 190             False  400.0  50.0 NaN  ...  3.0         NaN
# 189             False  400.0  50.0 NaN  ...  3.0         NaN
# 188             False  400.0  50.0 NaN  ...  3.0         NaN
# 230             False  400.0  50.0 NaN  ...  3.0         NaN
# 253             False  400.0  50.0 NaN  ...  3.0         NaN
# 232             False  400.0  50.0 NaN  ...  3.0         NaN
# 231             False  400.0  50.0 NaN  ...  3.0         NaN
#
#      dataset.split_ratio    a1  pointwise.AOPC_deletion  \
# 149                  0.8  0.40                      NaN
# 155                  0.8  0.40                      NaN
# 170                  0.8  0.80                      NaN
# 96                   0.8  0.05                      NaN
# 81                   0.8  0.05                      NaN
# 176                  0.8  0.80                      NaN
# 182                  0.8  0.80                      NaN
# 80                   0.8  0.05                      NaN
# 128                  0.8  0.20                      NaN
# 161                  0.8  0.40                      NaN
# 95                   0.8  0.05                      NaN
# 119                  0.8  0.10                      NaN
# 106                  0.8  0.10                      NaN
# 94                   0.8  0.05                      NaN
# 87                   0.8  0.05                      NaN
# 140                  0.8  0.20                      NaN
# 88                   0.8  0.05                      NaN
# 134                  0.8  0.20                      NaN
# 112                  0.8  0.10                      NaN
# 118                  0.8  0.10                      NaN
# 167                  0.8  0.80                      NaN
# 168                  0.8  0.80                      NaN
# 169                  0.8  0.80                      NaN
# 78                   0.8  0.05                      NaN
# 103                  0.8  0.10                      NaN
# 126                  0.8  0.20                      NaN
# 127                  0.8  0.20                      NaN
# 146                  0.8  0.40                      NaN
# 147                  0.8  0.40                      NaN
# 105                  0.8  0.10                      NaN
# 104                  0.8  0.10                      NaN
# 125                  0.8  0.20                      NaN
# 77                   0.8  0.05                      NaN
# 79                   0.8  0.05                      NaN
# 148                  0.8  0.40                      NaN
# 245                  0.8   NaN                      NaN
# 203                  0.8   NaN                      NaN
# 254                  0.8   NaN                      NaN
# 224                  0.8   NaN                      NaN
# 233                  0.8   NaN                      NaN
# 239                  0.8   NaN                      NaN
# 191                  0.8   NaN                      NaN
# 197                  0.8   NaN                      NaN
# 260                  0.8   NaN                      NaN
# 212                  0.8   NaN                      NaN
# 218                  0.8   NaN                      NaN
# 266                  0.8   NaN                      NaN
# 251                  0.8   NaN                      NaN
# 209                  0.8   NaN                      NaN
# 211                  0.8   NaN                      NaN
# 210                  0.8   NaN                      NaN
# 252                  0.8   NaN                      NaN
# 190                  0.8   NaN                      NaN
# 189                  0.8   NaN                      NaN
# 188                  0.8   NaN                      NaN
# 230                  0.8   NaN                      NaN
# 253                  0.8   NaN                      NaN
# 232                  0.8   NaN                      NaN
# 231                  0.8   NaN                      NaN
#
#     pointwise.AOPC_insertion  pointwise.Sufficiency  \
# 149                      NaN                    NaN
# 155                      NaN                    NaN
# 170                      NaN                    NaN
# 96                       NaN                    NaN
# 81                       NaN                    NaN
# 176                      NaN                    NaN
# 182                      NaN                    NaN
# 80                       NaN                    NaN
# 128                      NaN                    NaN
# 161                      NaN                    NaN
# 95                       NaN                    NaN
# 119                      NaN                    NaN
# 106                      NaN                    NaN
# 94                       NaN                    NaN
# 87                       NaN                    NaN
# 140                      NaN                    NaN
# 88                       NaN                    NaN
# 134                      NaN                    NaN
# 112                      NaN                    NaN
# 118                      NaN                    NaN
# 167                      NaN                    NaN
# 168                      NaN                    NaN
# 169                      NaN                    NaN
# 78                       NaN                    NaN
# 103                      NaN                    NaN
# 126                      NaN                    NaN
# 127                      NaN                    NaN
# 146                      NaN                    NaN
# 147                      NaN                    NaN
# 105                      NaN                    NaN
# 104                      NaN                    NaN
# 125                      NaN                    NaN
# 77                       NaN                    NaN
# 79                       NaN                    NaN
# 148                      NaN                    NaN
# 245                      NaN                    NaN
# 203                      NaN                    NaN
# 254                      NaN                    NaN
# 224                      NaN                    NaN
# 233                      NaN                    NaN
# 239                      NaN                    NaN
# 191                      NaN                    NaN
# 197                      NaN                    NaN
# 260                      NaN                    NaN
# 212                      NaN                    NaN
# 218                      NaN                    NaN
# 266                      NaN                    NaN
# 251                      NaN                    NaN
# 209                      NaN                    NaN
# 211                      NaN                    NaN
# 210                      NaN                    NaN
# 252                      NaN                    NaN
# 190                      NaN                    NaN
# 189                      NaN                    NaN
# 188                      NaN                    NaN
# 230                      NaN                    NaN
# 253                      NaN                    NaN
# 232                      NaN                    NaN
# 231                      NaN                    NaN
#
#      pointwise.Comprehensiveness  dataset.a9  dataset.a10
# 149                          NaN         NaN          NaN
# 155                          NaN         NaN          NaN
# 170                          NaN         NaN          NaN
# 96                           NaN         NaN          NaN
# 81                           NaN         NaN          NaN
# 176                          NaN         NaN          NaN
# 182                          NaN         NaN          NaN
# 80                           NaN         NaN          NaN
# 128                          NaN         NaN          NaN
# 161                          NaN         NaN          NaN
# 95                           NaN         NaN          NaN
# 119                          NaN         NaN          NaN
# 106                          NaN         NaN          NaN
# 94                           NaN         NaN          NaN
# 87                           NaN         NaN          NaN
# 140                          NaN         NaN          NaN
# 88                           NaN         NaN          NaN
# 134                          NaN         NaN          NaN
# 112                          NaN         NaN          NaN
# 118                          NaN         NaN          NaN
# 167                          NaN         NaN          NaN
# 168                          NaN         NaN          NaN
# 169                          NaN         NaN          NaN
# 78                           NaN         NaN          NaN
# 103                          NaN         NaN          NaN
# 126                          NaN         NaN          NaN
# 127                          NaN         NaN          NaN
# 146                          NaN         NaN          NaN
# 147                          NaN         NaN          NaN
# 105                          NaN         NaN          NaN
# 104                          NaN         NaN          NaN
# 125                          NaN         NaN          NaN
# 77                           NaN         NaN          NaN
# 79                           NaN         NaN          NaN
# 148                          NaN         NaN          NaN
# 245                          NaN         0.7         0.75
# 203                          NaN         0.5         0.75
# 254                          NaN         0.8         0.75
# 224                          NaN         0.6         0.75
# 233                          NaN         0.7         0.75
# 239                          NaN         0.7         0.75
# 191                          NaN         0.5         0.75
# 197                          NaN         0.5         0.75
# 260                          NaN         0.8         0.75
# 212                          NaN         0.6         0.75
# 218                          NaN         0.6         0.75
# 266                          NaN         0.8         0.75
# 251                          NaN         0.8         0.75
# 209                          NaN         0.6         0.75
# 211                          NaN         0.6         0.75
# 210                          NaN         0.6         0.75
# 252                          NaN         0.8         0.75
# 190                          NaN         0.5         0.75
# 189                          NaN         0.5         0.75
# 188                          NaN         0.5         0.75
# 230                          NaN         0.7         0.75
# 253                          NaN         0.8         0.75
# 232                          NaN         0.7         0.75
# 231                          NaN         0.7         0.75
#
# [59 rows x 63 columns]

# %%
raw_records = [extract_run_record(d) for d in run_dirs]
records = [apply_key_aliases(r, KEY_ALIASES) for r in raw_records]
df = pd.DataFrame(records)



# Focus on var_local / var_nonlocal (as requested)
df = df[df["dataset"].isin(DATASETS_OF_INTEREST)].copy()

# Optional: sort by dataset then AUPRC (lag-sensitive if available)
sort_cols = [c for c in ["dataset", "pairwise.ls.auprc", "clf.auprc", "clf.auroc"] if c in df.columns]
if sort_cols:
    df = df.sort_values(sort_cols, ascending=[True] + [False]*(len(sort_cols)-1))

print_discovered_hyperparams(df)

# Show a compact table first
show_cols = [
    "dataset", "model", "interaction_method",
    "a1", "noise", "tau_max", "num_permutations",
    "model.d_model", "model.layers", "model.hidden",
    "clf.f1", "clf.auroc", "clf.auprc",
    "pairwise.ls.f1", 
    "pairwise.ls.auroc", 
    "pairwise.ls.auprc",
    "pairwise.la.f1", 
    "pairwise.la.auroc", 
    "pairwise.la.auprc",
    "pairwise.lag_locality.mean_lag_error",
    "pairwise.strength.spearman",
    "run_dir",
]
show_cols = [c for c in show_cols if c in df.columns]

display(df[show_cols].reset_index(drop=True).head(50))

# Save for LaTeX / Excel
out_tsv = "results_summary_var.tsv"
df.to_csv(out_tsv, sep="\t", index=False)
print(f"✅ Saved full table to {out_tsv}")
# Out:
# 🔎 Discovered hyperparams in run dirs:
#   a1: [0.05, 0.1, 0.2, 0.4, 0.8]
#   dataset: ['var_local', 'var_nonlocal']
#   dataset.a1: [0.05, 0.1, 0.2, 0.4, 0.8]
#   dataset.a9: [0.5, 0.6, 0.7, 0.8]
#   dataset.name: ['var_local', 'var_nonlocal']
#   model: ['lstm', 'transformer']
#          dataset        model interaction_method    a1  noise  clf.f1  \
# 0      var_local  transformer               None  0.40   0.05  0.9647
# 1      var_local  transformer               None  0.40   0.05  0.9722
# 2      var_local  transformer               None  0.80   0.05  0.9859
# 3      var_local  transformer               None  0.05   0.05  0.8667
# 4      var_local  transformer               None  0.05   0.05  0.9783
# 5      var_local  transformer               None  0.80   0.05  0.9655
# 6      var_local  transformer               None  0.80   0.05  0.9412
# 7      var_local  transformer               None  0.05   0.05  0.9091
# 8      var_local  transformer               None  0.20   0.05  0.9351
# 9      var_local  transformer               None  0.40   0.05  0.8506
# 10     var_local  transformer               None  0.05   0.05  0.8395
# 11     var_local  transformer               None  0.10   0.05  0.8736
# 12     var_local  transformer               None  0.10   0.05  0.8831
# 13     var_local  transformer               None  0.05   0.05  0.8780
# 14     var_local  transformer               None  0.05   0.05  0.8636
# 15     var_local  transformer               None  0.20   0.05  0.8889
# 16     var_local  transformer               None  0.05   0.05  0.8947
# 17     var_local  transformer               None  0.20   0.05  0.8696
# 18     var_local  transformer               None  0.10   0.05  0.8916
# 19     var_local  transformer               None  0.10   0.05  0.7119
# 20     var_local         lstm               None  0.80   0.05  0.7302
# 21     var_local         lstm               None  0.80   0.05  0.7619
# 22     var_local         lstm               None  0.80   0.05  0.6765
# 23     var_local         lstm               None  0.05   0.05  0.6824
# 24     var_local         lstm               None  0.10   0.05  0.6947
# 25     var_local         lstm               None  0.20   0.05  0.7097
# 26     var_local         lstm               None  0.20   0.05  0.6667
# 27     var_local         lstm               None  0.40   0.05  0.7436
# 28     var_local         lstm               None  0.40   0.05  0.6585
# 29     var_local         lstm               None  0.10   0.05  0.6667
# 30     var_local         lstm               None  0.10   0.05  0.6667
# 31     var_local         lstm               None  0.20   0.05  0.6804
# 32     var_local         lstm               None  0.05   0.05  0.6250
# 33     var_local         lstm               None  0.05   0.05  0.5517
# 34     var_local         lstm               None  0.40   0.05  0.4561
# 35  var_nonlocal  transformer               None   NaN   0.05  0.9647
# 36  var_nonlocal  transformer               None   NaN   0.05  0.9398
# 37  var_nonlocal  transformer               None   NaN   0.05  0.9792
# 38  var_nonlocal  transformer               None   NaN   0.05  0.9663
# 39  var_nonlocal  transformer               None   NaN   0.05  0.9744
# 40  var_nonlocal  transformer               None   NaN   0.05  0.9487
# 41  var_nonlocal  transformer               None   NaN   0.05  0.9535
# 42  var_nonlocal  transformer               None   NaN   0.05  0.9524
# 43  var_nonlocal  transformer               None   NaN   0.05  0.9375
# 44  var_nonlocal  transformer               None   NaN   0.05  0.9143
# 45  var_nonlocal  transformer               None   NaN   0.05  0.9684
# 46  var_nonlocal  transformer               None   NaN   0.05  0.9000
# 47  var_nonlocal         lstm               None   NaN   0.05  0.8049
# 48  var_nonlocal         lstm               None   NaN   0.05  0.8764
# 49  var_nonlocal         lstm               None   NaN   0.05  0.7949
#
#     clf.auroc  clf.auprc  pairwise.ls.f1  pairwise.ls.auroc  \
# 0      1.0000     1.0000             NaN                NaN
# 1      1.0000     1.0000             NaN                NaN
# 2      0.9987     0.9985             NaN                NaN
# 3      0.9969     0.9968             NaN                NaN
# 4      0.9955     0.9966             NaN                NaN
# 5      0.9949     0.9960             NaN                NaN
# 6      0.9923     0.9909             NaN                NaN
# 7      0.9905     0.9906             NaN                NaN
# 8      0.9894     0.9895             NaN                NaN
# 9      0.9881     0.9874             NaN                NaN
# 10     0.9821     0.9768             NaN                NaN
# 11     0.9718     0.9763             NaN                NaN
# 12     0.9761     0.9739             NaN                NaN
# 13     0.9675     0.9738             NaN                NaN
# 14     0.9681     0.9726             NaN                NaN
# 15     0.9681     0.9724             NaN                NaN
# 16     0.9612     0.9653             NaN                NaN
# 17     0.9637     0.9651             NaN                NaN
# 18     0.9644     0.9645             NaN                NaN
# 19     0.9422     0.9250             NaN                NaN
# 20     0.8492     0.8468             NaN                NaN
# 21     0.8393     0.8312             NaN                NaN
# 22     0.7989     0.7925             NaN                NaN
# 23     0.7302     0.7757             NaN                NaN
# 24     0.6521     0.7450             NaN                NaN
# 25     0.8227     0.7413             NaN                NaN
# 26     0.6988     0.7350             NaN                NaN
# 27     0.7976     0.7044             NaN                NaN
# 28     0.7404     0.7043             NaN                NaN
# 29     0.6528     0.6794             NaN                NaN
# 30     0.7721     0.6760             NaN                NaN
# 31     0.6792     0.6673             NaN                NaN
# 32     0.5956     0.5786             NaN                NaN
# 33     0.5965     0.5626             NaN                NaN
# 34     0.5880     0.5135             NaN                NaN
# 35     1.0000     1.0000             NaN                NaN
# 36     0.9994     0.9995             NaN                NaN
# 37     0.9987     0.9991             NaN                NaN
# 38     0.9981     0.9987             NaN                NaN
# 39     0.9975     0.9976             NaN                NaN
# 40     0.9937     0.9947             NaN                NaN
# 41     0.9931     0.9942             NaN                NaN
# 42     0.9893     0.9910             NaN                NaN
# 43     0.9910     0.9885             NaN                NaN
# 44     0.9886     0.9857             NaN                NaN
# 45     0.9813     0.9854             NaN                NaN
# 46     0.9889     0.9848             NaN                NaN
# 47     0.9021     0.9235             NaN                NaN
# 48     0.9110     0.9043             NaN                NaN
# 49     0.8772     0.8591             NaN                NaN
#
#     pairwise.ls.auprc  pairwise.la.f1  pairwise.la.auroc  pairwise.la.auprc  \
# 0                 NaN             NaN                NaN                NaN
# 1                 NaN             NaN                NaN                NaN
# 2                 NaN             NaN                NaN                NaN
# 3                 NaN             NaN                NaN                NaN
# 4                 NaN             NaN                NaN                NaN
# 5                 NaN             NaN                NaN                NaN
# 6                 NaN             NaN                NaN                NaN
# 7                 NaN             NaN                NaN                NaN
# 8                 NaN             NaN                NaN                NaN
# 9                 NaN             NaN                NaN                NaN
# 10                NaN             NaN                NaN                NaN
# 11                NaN             NaN                NaN                NaN
# 12                NaN             NaN                NaN                NaN
# 13                NaN             NaN                NaN                NaN
# 14                NaN             NaN                NaN                NaN
# 15                NaN             NaN                NaN                NaN
# 16                NaN             NaN                NaN                NaN
# 17                NaN             NaN                NaN                NaN
# 18                NaN             NaN                NaN                NaN
# 19                NaN             NaN                NaN                NaN
# 20                NaN             NaN                NaN                NaN
# 21                NaN             NaN                NaN                NaN
# 22                NaN             NaN                NaN                NaN
# 23                NaN             NaN                NaN                NaN
# 24                NaN             NaN                NaN                NaN
# 25                NaN             NaN                NaN                NaN
# 26                NaN             NaN                NaN                NaN
# 27                NaN             NaN                NaN                NaN
# 28                NaN             NaN                NaN                NaN
# 29                NaN             NaN                NaN                NaN
# 30                NaN             NaN                NaN                NaN
# 31                NaN             NaN                NaN                NaN
# 32                NaN             NaN                NaN                NaN
# 33                NaN             NaN                NaN                NaN
# 34                NaN             NaN                NaN                NaN
# 35                NaN             NaN                NaN                NaN
# 36                NaN             NaN                NaN                NaN
# 37                NaN             NaN                NaN                NaN
# 38                NaN             NaN                NaN                NaN
# 39                NaN             NaN                NaN                NaN
# 40                NaN             NaN                NaN                NaN
# 41                NaN             NaN                NaN                NaN
# 42                NaN             NaN                NaN                NaN
# 43                NaN             NaN                NaN                NaN
# 44                NaN             NaN                NaN                NaN
# 45                NaN             NaN                NaN                NaN
# 46                NaN             NaN                NaN                NaN
# 47                NaN             NaN                NaN                NaN
# 48                NaN             NaN                NaN                NaN
# 49                NaN             NaN                NaN                NaN
#
#     pairwise.lag_locality.mean_lag_error  pairwise.strength.spearman  \
# 0                                    NaN                         NaN
# 1                                    NaN                         NaN
# 2                                    NaN                         NaN
# 3                                    NaN                         NaN
# 4                                    NaN                         NaN
# 5                                    NaN                         NaN
# 6                                    NaN                         NaN
# 7                                    NaN                         NaN
# 8                                    NaN                         NaN
# 9                                    NaN                         NaN
# 10                                   NaN                         NaN
# 11                                   NaN                         NaN
# 12                                   NaN                         NaN
# 13                                   NaN                         NaN
# 14                                   NaN                         NaN
# 15                                   NaN                         NaN
# 16                                   NaN                         NaN
# 17                                   NaN                         NaN
# 18                                   NaN                         NaN
# 19                                   NaN                         NaN
# 20                                   NaN                         NaN
# 21                                   NaN                         NaN
# 22                                   NaN                         NaN
# 23                                   NaN                         NaN
# 24                                   NaN                         NaN
# 25                                   NaN                         NaN
# 26                                   NaN                         NaN
# 27                                   NaN                         NaN
# 28                                   NaN                         NaN
# 29                                   NaN                         NaN
# 30                                   NaN                         NaN
# 31                                   NaN                         NaN
# 32                                   NaN                         NaN
# 33                                   NaN                         NaN
# 34                                   NaN                         NaN
# 35                                   NaN                         NaN
# 36                                   NaN                         NaN
# 37                                   NaN                         NaN
# 38                                   NaN                         NaN
# 39                                   NaN                         NaN
# 40                                   NaN                         NaN
# 41                                   NaN                         NaN
# 42                                   NaN                         NaN
# 43                                   NaN                         NaN
# 44                                   NaN                         NaN
# 45                                   NaN                         NaN
# 46                                   NaN                         NaN
# 47                                   NaN                         NaN
# 48                                   NaN                         NaN
# 49                                   NaN                         NaN
#
#                                               run_dir
# 0   ../runs_new/var_local_a10.4_n400_d3_L50_split_...
# 1   ../runs_new/var_local_a10.4_n400_d3_L50_split_...
# 2   ../runs_new/var_local_a10.8_n400_d3_L50_split_...
# 3   ../runs_new/var_local_a10.05_n400_d3_L50_split...
# 4   ../runs_new/var_local_a10.05_n400_d3_L50_split...
# 5   ../runs_new/var_local_a10.8_n400_d3_L50_split_...
# 6   ../runs_new/var_local_a10.8_n400_d3_L50_split_...
# 7   ../runs_new/var_local_a10.05_n400_d3_L50_split...
# 8   ../runs_new/var_local_a10.2_n400_d3_L50_split_...
# 9   ../runs_new/var_local_a10.4_n400_d3_L50_split_...
# 10  ../runs_new/var_local_a10.05_n400_d3_L50_split...
# 11  ../runs_new/var_local_a10.1_n400_d3_L50_split_...
# 12  ../runs_new/var_local_a10.1_n400_d3_L50_split_...
# 13  ../runs_new/var_local_a10.05_n400_d3_L50_split...
# 14  ../runs_new/var_local_a10.05_n400_d3_L50_split...
# 15  ../runs_new/var_local_a10.2_n400_d3_L50_split_...
# 16  ../runs_new/var_local_a10.05_n400_d3_L50_split...
# 17  ../runs_new/var_local_a10.2_n400_d3_L50_split_...
# 18  ../runs_new/var_local_a10.1_n400_d3_L50_split_...
# 19  ../runs_new/var_local_a10.1_n400_d3_L50_split_...
# 20  ../runs_new/var_local_a10.8_n400_d3_L50_split_...
# 21  ../runs_new/var_local_a10.8_n400_d3_L50_split_...
# 22  ../runs_new/var_local_a10.8_n400_d3_L50_split_...
# 23  ../runs_new/var_local_a10.05_n400_d3_L50_split...
# 24  ../runs_new/var_local_a10.1_n400_d3_L50_split_...
# 25  ../runs_new/var_local_a10.2_n400_d3_L50_split_...
# 26  ../runs_new/var_local_a10.2_n400_d3_L50_split_...
# 27  ../runs_new/var_local_a10.4_n400_d3_L50_split_...
# 28  ../runs_new/var_local_a10.4_n400_d3_L50_split_...
# 29  ../runs_new/var_local_a10.1_n400_d3_L50_split_...
# 30  ../runs_new/var_local_a10.1_n400_d3_L50_split_...
# 31  ../runs_new/var_local_a10.2_n400_d3_L50_split_...
# 32  ../runs_new/var_local_a10.05_n400_d3_L50_split...
# 33  ../runs_new/var_local_a10.05_n400_d3_L50_split...
# 34  ../runs_new/var_local_a10.4_n400_d3_L50_split_...
# 35  ../runs_new/var_nonlocal_a100.75_a90.7_edge10[...
# 36  ../runs_new/var_nonlocal_a100.75_a90.5_edge10[...
# 37  ../runs_new/var_nonlocal_a100.75_a90.8_edge10[...
# 38  ../runs_new/var_nonlocal_a100.75_a90.6_edge10[...
# 39  ../runs_new/var_nonlocal_a100.75_a90.7_edge10[...
# 40  ../runs_new/var_nonlocal_a100.75_a90.7_edge10[...
# 41  ../runs_new/var_nonlocal_a100.75_a90.5_edge10[...
# 42  ../runs_new/var_nonlocal_a100.75_a90.5_edge10[...
# 43  ../runs_new/var_nonlocal_a100.75_a90.8_edge10[...
# 44  ../runs_new/var_nonlocal_a100.75_a90.6_edge10[...
# 45  ../runs_new/var_nonlocal_a100.75_a90.6_edge10[...
# 46  ../runs_new/var_nonlocal_a100.75_a90.8_edge10[...
# 47  ../runs_new/var_nonlocal_a100.75_a90.8_edge10[...
# 48  ../runs_new/var_nonlocal_a100.75_a90.6_edge10[...
# 49  ../runs_new/var_nonlocal_a100.75_a90.6_edge10[...
# ✅ Saved full table to results_summary_var.tsv
